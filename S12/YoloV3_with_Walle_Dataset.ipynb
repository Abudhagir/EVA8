# %% [markdown]
# ![open in cloab]

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# fatal: destination path 'YoloV3' already exists and is not an empty directory.

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.13.1 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090 Ti', major=8, minor=6, total_memory=24247MB, multi_processor_count=84)

# %%
ls
# Out:
#  annotation_tool/   output/        runs/            utils/
#  cfg/               __pycache__/   test.py          vim.exe.stackdump
#  data/              README.md      ting             weights/
#  detect.py          results.json   train.py         YoloV3/
#  models.py          results.png   'ubdivisions=1'

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(epochs=3, batch_size=3, accumulate=4, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090 Ti', total_memory=24247MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100%|
# Caching images (0.0GB): 100%|██████████████████| 20/20 [00:00<00:00, 315.70it/s]
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100%|
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(epochs=300, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=False, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090 Ti', total_memory=24247MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100%|
# Caching images (0.0GB): 100%|██████████████████| 20/20 [00:00<00:00, 321.56it/s]
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100%|
# ...

# %%
# !python detect.py --cfg cfg/yolov3-custom.cfg --conf-thres 0.3 --output out_out
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='out_out', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090 Ti', total_memory=24247MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /home/bvrit/anaconda3/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/20 data/customdata/images/img001.jpg: 512x512 1 walles, Done. (0.007s)
# ...

# %%
Image(filename='data/customdata/images/img012.jpg', width=500)

# %%
Image(filename='out_out/img012.jpg', width=500)

# %%
Image(filename='out_out/img001.jpg', width=600)

# %%
Image(filename='out_out/img002.jpg', width=600)

# %%
Image(filename='out_out/img003.jpg', width=600)

# %%
Image(filename='out_out/img004.jpg', width=600)

# %%
Image(filename='out_out/img005.jpg', width=600)

# %%
Image(filename='out_out/img005.jpg', width=600)

# %%
Image(filename='out_out/img006.jpg', width=600)

# %%
Image(filename='out_out/img007.jpg', width=600)

# %%
Image(filename='out_out/img008.jpg', width=600)

# %%
Image(filename='out_out/img009.jpg', width=600)

# %%
Image(filename='out_out/img010.jpg', width=600)
